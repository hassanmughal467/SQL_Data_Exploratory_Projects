# %%
import sys
import pypyodbc as odbc

# %%
# Connection String

DRIVER = 'SQL Server'
SERVER_NAME = 'DESKTOP-R7DOSJA'
DATABASE_NAME = 'Cryptocurrency'
conn_string = f"""
        Driver={{{DRIVER}}};
        Server={SERVER_NAME};
        Database={DATABASE_NAME};
        Trust_Connection=yes;
    """

# %%
# Insert Data into sql
def insert_Data(conn_string):
    try:
        conn = odbc.connect(conn_string)
    except Exception as e:
        print(e)
        print('task is terminated')
        sys.exit()
    else:
        cursor = conn.cursor()


    insert_statement = """INSERT INTO crypto
        VALUES (?, ?, ?, ?,?,?)
    """

    try:
        for record in records:
            print(record)
            cursor.execute(insert_statement, record)        
    except Exception as e:
        cursor.rollback()
        print(e.value)
        print('transaction rolled back')
    else:
        print('records inserted successfully')
        cursor.commit()
        cursor.close()
    finally:
        if conn.connected == 1:
            print('connection closed')
            conn.close()

# %%
# Get Data from sql
def Get_Data(conn_string):
    try:
        conn = odbc.connect(conn_string)
    except Exception as e:
        print(e)
        print('task is terminated')
        sys.exit()
    else:
        cursor = conn.cursor()


    get_statement = """SELECT * FROM crypto"""

    try:
        cursor.execute(get_statement)   
        for row in cursor:
            print(f'{row}')
    except Exception as e:
        cursor.rollback()
        print(e.value)
        print('transaction rolled back')
    else:
        print('records get successfully')
        cursor.commit()
        cursor.close()
    finally:
        if conn.connected == 1:
            print('connection closed')
            conn.close()

# %%
 Get_Data(conn_string)
# Out:
# ('Bitcoin', '45695.34720957006', '0.17150557', '0.17150557', '0.17150557', '0.17150557')
# ('Ethereum', '3321.6144760971106', '-0.07005605', '-0.07005605', '-0.07005605', '-0.07005605')
# ('Cardano', '2.40973118449449', '0.3380709', '0.3380709', '0.3380709', '0.3380709')
# ('Binance Coin', '407.8182913043004', '0.46928949', '0.46928949', '0.46928949', '0.46928949')
# ('Tether', '1.00022392902636', '0.00274039', '0.00274039', '0.00274039', '0.00274039')
# ('Solana', '181.0146334776714', '1.2055658', '1.2055658', '1.2055658', '1.2055658')
# ('XRP', '1.08138972040175', '0.37818838', '0.37818838', '0.37818838', '0.37818838')
# ('Dogecoin', '0.24415811531793', '0.25495407', '0.25495407', '0.25495407', '0.25495407')
# ('Polkadot', '29.66455270921802', '0.11548366', '0.11548366', '0.11548366', '0.11548366')
# ('USD Coin', '1.00018743628028', '-0.00849646', '-0.00849646', '-0.00849646', '-0.00849646')
# ...

# %%
def update_data(conn_string):
    try:
        conn = odbc.connect(conn_string)
    except Exception as e:
        print(e)
        print('task is terminated')
        sys.exit()
    else:
        cursor = conn.cursor()

    #get_statement = 'update crypto  set curr_price= ? where curr_id= ?',('34643757',1)

    try:
        cursor.execute('update crypto  set curr_price= ? where curr_id= ?',('34643757',1))   
    except Exception as e:
        cursor.rollback()
        #print(e.value)
        print('transaction rolled back')
    else:
        print('records updated successfully')
        cursor.commit()
        cursor.close()
    finally:
        if conn.connected == 1:
            print('connection closed')
            conn.close()

# %%
update_data(conn_string)
# Out:
# records updated successfully
# connection closed

# %%
def delete_data(conn_string):
    try:
        conn = odbc.connect(conn_string)
    except Exception as e:
        print(e)
        print('task is terminated')
        sys.exit()
    else:
        cursor = conn.cursor()


    #del_statement = 'delete from crypto where curr_id= ?',(20)

    try:
        cursor.execute("""delete from crypto where curr_id= ?""",(20,))   
    except Exception as e:
        cursor.rollback()
        print(e)
        print('transaction rolled back')
    else:
        print('records deleted successfully')
        cursor.commit()
        cursor.close()
    finally:
        if conn.connected == 1:
            print('connection closed')
            conn.close()

# %%
delete_data(conn_string)
# Out:
# records deleted successfully
# connection closed
